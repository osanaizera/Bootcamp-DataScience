# %% [markdown]
# <a href="https://colab.research.google.com/github/osanaizera/Bootcamp-DataScience/blob/main/BootCampOsanai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Caderno de exploração de dados do DATASUS

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A110012189_28_143_208.csv", encoding="ISO-8859-1",
                    skiprows=3, sep=";", engine='python', skipfooter=12, thousands = ".", decimal =",")

# %%
dados
# Out:
#       Unidade da Federação     2008/Jan  ...      2021/Mar         Total
# 0              11 Rondônia   1388528.39  ...  1.102331e+07  9.964113e+08
# 1                  12 Acre    902416.00  ...  4.077046e+06  4.500485e+08
# 2              13 Amazonas   4735529.42  ...  2.203218e+07  1.917248e+09
# 3               14 Roraima    657889.53  ...  3.985530e+06  3.288770e+08
# 4                  15 Pará  18864744.11  ...  3.327639e+07  4.705309e+09
# 5                 16 Amapá   1120973.34  ...  3.188211e+06  3.098601e+08
# 6             17 Tocantins   3441592.69  ...  1.357751e+06  1.020028e+09
# 7              21 Maranhão  10723506.39  ...  3.966368e+07  3.871069e+09
# 8                 22 Piauí   7985142.43  ...  2.001833e+07  2.280889e+09
# 9                 23 Ceará  15539821.90  ...  6.207962e+07  6.591837e+09
# 10  24 Rio Grande do Norte   5947814.08  ...  2.330650e+07  2.660122e+09
# 11              25 Paraíba  10723002.45  ...  2.575090e+07  2.614919e+09
# ...

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x="Unidade da Federação",y="2008/Set", kind="bar", figsize=(10,7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2008/Set", kind="bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

plt.title("Valor em R$ gasto em Setembro de 2008, por UF")
# Out:
# Text(0.5, 1.0, 'Valor em R$ gasto em Setembro de 2008, por UF')

# %%
ax = dados.plot(x="Unidade da Federação",y="2021/Mar", kind="bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))

plt.title("Valor em R$ gasto em Março de 2021, por UF")
# Out:
# Text(0.5, 1.0, 'Valor em R$ gasto em Março de 2021, por UF')

# %%
dados = pd.read_csv("/content/A140201189_28_143_208.csv", encoding="ISO-8859-1",
                    skiprows=3, sep=";", engine='python', skipfooter=12, thousands = ".", decimal =",")

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  ...     2021/Mar          Total
# 0              11 Rondônia         -  ...   4732441.04   996411254.68
# 1                  12 Acre         -  ...   1137341.65   450048530.47
# 2              13 Amazonas         -  ...   6799060.80  1917247936.05
# 3               14 Roraima         -  ...   2381844.31   328876965.09
# 4                  15 Pará         -  ...  13069564.31  4705309002.29
# 5                 16 Amapá         -  ...    989155.40   309860092.59
# 6             17 Tocantins         -  ...    928756.84  1020028272.64
# 7              21 Maranhão         -  ...  17294509.11  3871069498.04
# 8                 22 Piauí         -  ...   9542151.53  2280888802.74
# 9                 23 Ceará         -  ...  17173151.55  6591836650.18
# 10  24 Rio Grande do Norte         -  ...   8733455.36  2660122027.15
# 11              25 Paraíba         -  ...  12517894.05  2614919044.63
# ...

# %%
dados[["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()

# %%
colunas_usaveis
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov', '2020/Dez',
#        '2021/Jan', '2021/Fev', '2021/Mar', 'Total'],
#       dtype='object', length=165)

# %%
dados[colunas_usaveis]
# Out:
#      2007/Ago   2007/Set    2007/Out  ...     2021/Fev     2021/Mar          Total
# 0     4209.37   16397.03   133645.19  ...   6039419.59   4732441.04   996411254.68
# 1    10470.07   14001.71    86200.85  ...   2272733.90   1137341.65   450048530.47
# 2    35752.72   45570.64   416012.30  ...  13679358.06   6799060.80  1917247936.05
# 3     4785.91   11858.63    43852.67  ...   3044798.77   2381844.31   328876965.09
# 4   181159.29  433414.74  1893197.50  ...  23343222.94  13069564.31  4705309002.29
# 5    33672.74  104822.98   118378.28  ...   1534733.18    989155.40   309860092.59
# 6     4113.76   76633.06   343702.61  ...    416534.32    928756.84  1020028272.64
# 7   385330.18 1018352.93  2277717.78  ...  23260245.95  17294509.11  3871069498.04
# 8   220788.25  353468.67  1078182.68  ...  13636005.36   9542151.53  2280888802.74
# 9   357904.65  572356.18  1865065.71  ...  30186951.00  17173151.55  6591836650.18
# ...

# %%
colunas_usaveis.insert(0, "Unidade da Federação")

# %%
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]

# %%
usaveis = usaveis.set_index("Unidade da Federação")

# %%
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# ...

# %%
usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
selecionados = usaveis.loc[["12 Acre", "43 Rio Grande do Sul", "24 Rio Grande do Norte", "41 Paraná", "42 Santa Catarina"]]
usaveis = usaveis.drop("Total", axis=1)

# %%
selecionados.plot(figsize=(12,6))

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  6039419.59  4732441.04
# 12 Acre               10470.07  14001.71  ...  2272733.90  1137341.65
# 13 Amazonas           35752.72  45570.64  ... 13679358.06  6799060.80
# 14 Roraima             4785.91  11858.63  ...  3044798.77  2381844.31
# 15 Pará              181159.29 433414.74  ... 23343222.94 13069564.31
#
# [5 rows x 164 columns]

# %%
usaveis.T.plot(figsize=(12,6))
plt.legend(title='ESTADOS', bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
plot.legend( title='title', bbox_to_anchor=(1.05, 1), loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-05eece4b55a1> in <module>()
#       1
# ----> 2 plot.legend( title='title', bbox_to_anchor=(1.05, 1), loc='upper left')
#
# NameError: name 'plot' is not defined

# %%
selecionados = usaveis.loc[["12 Acre", "43 Rio Grande do Sul", "24 Rio Grande do Norte", "41 Paraná", "42 Santa Catarina"]]
selecionados = selecionados.drop("Total", axis=1)
ax = selecionados.T.plot( figsize=(12,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R${x:,.2f}"))
plt.legend(title='ESTADOS', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Gastos históricos com atendimentos por estado")
# Out:
# Text(0.5, 1.0, 'Gastos históricos com atendimentos por estado')
